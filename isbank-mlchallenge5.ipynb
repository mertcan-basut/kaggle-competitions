# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from IPython.display import display

# %% [markdown]
# ## Literature Survey
#
# - **Example [#]()**
#
# Lorem ipsum.
#
# - **Example [#]()**

# %%
data = pd.read_parquet("/kaggle/input/turkiye-is-bankasi-ml-challenge-5/train_final.parquet")
data.info()
print(data.shape)
display(data.describe())
data.head()

# %%
# TODO: Drop "id" column (not required for training)
# TODO: Categorize (1-12) and one-hot encode "month" column (months of the year) (time-series plot)
# TODO: Categorize and one-hot encode "carrier" column
# TODO: Categorize and one-hot encode "devicebrand" column
# TODO: Draw bar and pie plots for categoric columns and their relations between output columns
# TODO: Standardize or normalize numeric columns (histogram distribution and box plot analysis)
# TODO: Analyze features by observing correlations and use dimension reduction methods (?PCA, t-SNE)
# TODO: Create new columns from external data like ($save citation for literature survey): ?dönemsel enflasyon verisi, maaş ödenme günleri, (SGK ve devlet memurlarının maaş günleri vb…), resmi ve dini bayramlara ilişkin veriler, döviz kurları, mevsime göre ülkemizde görülen ortalama sıcaklık
# TODO: Create balanced train, test, and validation sets
# =REGRESSION=
# TODO: Create output columns for 9 different menus as the time spent on them
# TODO: 1. Generate random values for the missing output columns with the condition of being between 0 and n_seconds_3 (smallest known output value) (also can introduce a bias to ensure safety)
# OR
# TODO: 2. Fill missing output columns with 0s.
# TODO: Train models (?RandomForest, SVM, KNN, RidgeRegression) ($save citation for literature survey) with fine-tuned parameters (grid search)
# TODO: Calculate binary output by selecting top 3 menus with the most time spent
# TODO: Calculate performance metrics (?Jaccard score) for comparison
# =CLASSIFICATION=
# TODO: Create output columns for 9 different menus as binary
# TODO: Drop "n_seconds" columns
# OR
# TODO: Leave "n_seconds" columns as features
# TODO: Train models (?RandomForest, SVM, KNN) ($save citation for literature survey) with fine-tuned parameters (grid search)
# TODO: Calculate binary output by combining output columns
# TODO: Calculate performance metrics (?Jaccard score) for comparison
# TODO: Create a csv or parquet file with final predictions (11955 rows and a header) and submit (2 best submissions)

# %%
target = pd.read_parquet("/kaggle/input/turkiye-is-bankasi-ml-challenge-5/test_final.parquet")
